# %%
import certifi
certifi.where()
# Out:
# 'C:\\Users\\v.volkov\\AppData\\Roaming\\Python\\Python39\\site-packages\\certifi\\cacert.pem'

# %%
import ssl
print(ssl.get_default_verify_paths().openssl_cafile)
# Out:
# C:\Program Files\Common Files\ssl/cert.pem

# %%
import os
print(os.environ.get("SSL_CERT_FILE"))
print(os.environ.get("SSL_CERT_DIR"))
import ssl
ssl.get_default_verify_paths()
# Out:
# C:\temp\cacert-2024-03-11.pem
# None
# DefaultVerifyPaths(cafile='C:\\temp\\cacert-2024-03-11.pem', capath=None, openssl_cafile_env='SSL_CERT_FILE', openssl_cafile='C:\\Program Files\\Common Files\\ssl/cert.pem', openssl_capath_env='SSL_CERT_DIR', openssl_capath='C:\\Program Files\\Common Files\\ssl/certs')

# %%
import requests

try:
    response = requests.get('https://pypi.org/')
    print(response.status_code)
except Exception as e:
    print(e)
# Out:
# HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))

# %%
# python 3.11.0
# %pip install -q nest_asyncio xmltodict faiss-cpu==1.7.4 langchain==0.1.7 openai==1.12.0 tiktoken==0.6.0 langchain_community==0.0.20 langchain-openai==0.0.6 unstructured
# %pip install nest_asyncio xmltodict faiss-cpu langchain openai tiktoken langchain-openai
# %pip install python-dotenv
# python -m pip install python-certifi-win32
# python -m pip install certifi
# python -m certifi
# %pip install certifi
# python -m pip install --force-reinstall certifi
# Out:
# Could not fetch URL https://pypi.org/simple/python-dotenv/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/python-dotenv/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)'))) - skippingNote: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)'))': /simple/python-dotenv/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)'))': /simple/python-dotenv/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)'))': /simple/python-dotenv/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)'))': /simple/python-dotenv/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)'))': /simple/python-dotenv/
# ERROR: Could not find a version that satisfies the requirement python-dotenv (from versions: none)
# ERROR: No matching distribution found for python-dotenv

# %%
# python 3.11.4
# %pip install -r requirements.txt
# %pip install --upgrade pip
# %pip install google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client
# %pip install -U langchain-openai
# установка openssl
# Set-ExecutionPolicy Bypass -Scope Process -Force; [System.Net.ServicePointManager]::SecurityProtocol = [System.Net.ServicePointManager]::SecurityProtocol -bor 3072; iex ((New-Object System.Net.WebClient).DownloadString('https://chocolatey.org/install.ps1'))
# choco install openssl
# %pip install --upgrade httpx
# Out:
# Requirement already satisfied: httpx in c:\users\v.volkov\appdata\local\miniconda3\envs\env3114\lib\site-packages (0.27.0)
# Requirement already satisfied: anyio in c:\users\v.volkov\appdata\local\miniconda3\envs\env3114\lib\site-packages (from httpx) (4.3.0)
# Requirement already satisfied: certifi in c:\users\v.volkov\appdata\local\miniconda3\envs\env3114\lib\site-packages (from httpx) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\v.volkov\appdata\local\miniconda3\envs\env3114\lib\site-packages (from httpx) (1.0.5)
# Requirement already satisfied: idna in c:\users\v.volkov\appdata\local\miniconda3\envs\env3114\lib\site-packages (from httpx) (3.6)
# Requirement already satisfied: sniffio in c:\users\v.volkov\appdata\local\miniconda3\envs\env3114\lib\site-packages (from httpx) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\v.volkov\appdata\local\miniconda3\envs\env3114\lib\site-packages (from httpcore==1.*->httpx) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from googleapiclient.http import MediaIoBaseDownload
import httplib2
import google_auth_httplib2
import io
# from googleapiclient.discovery import build
import requests
from google.auth.transport.requests import Request
from google.auth.transport.requests import AuthorizedSession
import logging
logging.basicConfig(level=logging.DEBUG)

# найти на гуглдрайве файл, имя которого включает в себя uniquesubstringfromfilename и вернуть текст этого файла
# для получения сервис файла json надо настроить авторизацию гугл на google cloud
def getfilefromgoogledisk(uniquesubstringfromfilename=""):
    # Путь к файлу с учетными данными
    # "Копия ПРАВИЛА СТРАХОВАНИЯ ОТВЕТСТВЕННОСТИ АЭРОПОРТОВ И АВИАЦИОННЫХ ТОВАРОПРОИЗВОДИТЕЛЕЙ"
    
    SERVICE_ACCOUNT_FILE = 'googledriveutopian-theater-338909-30c6f2cd39b6.json'

    # Создание сервисного аккаунта
    credentials = service_account.Credentials.from_service_account_file(
            SERVICE_ACCOUNT_FILE, scopes=['https://www.googleapis.com/auth/drive'])
    h = httplib2.Http(".cache", disable_ssl_certificate_validation=True)
    authorized_http = google_auth_httplib2.AuthorizedHttp(credentials=credentials,http=h)
    
    # Создание сервиса Google Drive с использованием настроенного экземпляра AuthorizedHttp
    service = build('drive', 'v3', http=authorized_http)
    # Пример функции для получения списка файлов
    def list_files(keyword):
        try:
            results = service.files().list(
                pageSize=10, fields="nextPageToken, files(id, name)").execute()
            items = results.get('files', [])
            if not items:
                print('No files found.')
            else:
                print('Files:')
                for item in items:
                    if keyword in item['name']:
                        print(u'{0} ({1})'.format(item['name'], item['id']))
                        return item['id']
        except HttpError as error:
            print(f'An error occurred: {error}')
            items = None

    file_id=list_files(uniquesubstringfromfilename)

    # Получение метаданных файла для определения его типа
    file_metadata = service.files().get(fileId=file_id).execute()
    file_mime_type = file_metadata.get('mimeType')
    mime_type = 'text/plain' # Меняем MIME-тип на 'text/plain' для экспорта текста

    # Получение метаданных файла
    file_metadata = service.files().get(fileId=file_id).execute()
    file_mime_type = file_metadata.get('mimeType')

    # Определение, нужно ли использовать метод export
    if file_mime_type in ['application/vnd.google-apps.document', 'application/vnd.google-apps.spreadsheet', 'application/vnd.google-apps.presentation']:
        # Использование метода export для документов Google Docs, Sheets и Slides
        request = service.files().export_media(fileId=file_id, mimeType=mime_type)
    else:
        # Для других типов файлов используем метод get_media
        request = service.files().get_media(fileId=file_id)

    # Создание буфера для хранения текста
    text_content = io.BytesIO()

    # Загрузка текста в буфер
    downloader = MediaIoBaseDownload(text_content, request)
    done = False
    while done is False:
        status, done = downloader.next_chunk()
        print("Загружено {}%.".format(int(status.progress() * 100)))

    # Извлечение текста из буфера
    text_content.seek(0) # Перемещение указателя в начало буфера
    text = text_content.read().decode('utf-8') # Чтение и декодирование текста

    return text
print(getfilefromgoogledisk("АЭРОПОРТОВ И АВИАЦИОННЫХ ТОВАРОПРОИЗВОДИТЕЛЕЙ")[:1000]) # Вывод первых 1000 символов текста

# %% [markdown]
# ## Пример использования модуля кастомного chatGPT

# %%
from model import LLMModel

# использование кастомного chagpt через модуль
chunk = LLMModel(path_to_base="Simble.txt")
res = chunk.get_answer(query="На какой минимальный срок можно оформить КАСКО?")
print(res)

# %% [markdown]
# ## Пример использования простого API

# %%
import requests

# запросы в fastapi_example
response = requests.get("http://127.0.0.1:8000/")
print(response.text)

# %%
# запросы в fastapi_example
response = requests.get("http://127.0.0.1:8000/about")
print(response.text)

# %%
# запросы в fastapi_example
payload={"name":"Ivan", "description":"good item", "price":42.3}
response = requests.post("http://127.0.0.1:8000/users", json=payload)
print(response.text)

# %% [markdown]
# ## Пример использования API с кастомным chatGPT

# %%
# %pip show langchain-openai
# %pip show langchain

# %%
# Deprecated
# from langchain.embeddings.openai import OpenAIEmbeddings
# print(dir(OpenAIEmbeddings))
# print(OpenAIEmbeddings.__doc__)

# %%
from dotenv import load_dotenv
import os
# os.environ.clear()
# load_dotenv(".env")
# print(os.environ.get("SSL_CERT_FILE"))
# print(os.environ.get('REQUESTS_CA_BUNDLE'))
from httpx import HTTPTransport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from dotenv import load_dotenv
#       2 import os
#       3 # os.environ.clear()
#       4 # load_dotenv(".env")
#       5 # print(os.environ.get("SSL_CERT_FILE"))
#       6 # print(os.environ.get('REQUESTS_CA_BUNDLE'))
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
from dotenv import load_dotenv
import os
os.environ.clear()
load_dotenv(".env")
print(os.environ.get("SSL_CERT_FILE"))
print(os.environ.get('REQUESTS_CA_BUNDLE'))

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
from httpx import HTTPTransport
from unittest.mock import patch
from langchain_openai import OpenAIEmbeddings
# print(dir(OpenAIEmbeddings))
# print(OpenAIEmbeddings.__doc__)

# from langchain_openai import OpenAIEmbeddingsc:\temp\KasperskyCertification.crt
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.docstore.document import Document

import openai
openai.api_key = os.environ.get("OPENAI_API_KEY")
openai.verify_ssl_certs = False
# print(os.environ.get("OPENAI_API_KEY"))

# Укажите путь к директории
folder_path = ''
# задаем system
default_system = '''Ты-консультант по ПРАВИЛАМ СТРАХОВАНИЯ.
Ответь на вопрос клиента на основе переданного тебе документа с соответствующими правилами. 
Не придумывай ничего от себя, отвечай максимально по документу. 
Не упоминай Документ с информацией для ответа клиенту. 
Клиент ничего не должен знать про Документ с информацией для ответа клиенту
'''

# Проверяем существование файлов
def check_files_exist(folder_path, file_names):
    for file_name in file_names:
        file_path = os.path.join(folder_path, file_name)
        if os.path.exists(file_path):
            pass
        else:
            print(f"Файл '{file_name}' не найден в директории '{folder_path}'.")
            return False
    return True



class LLMModel():
    def __init__(self, folder_path: str, sep: str = " ", ch_size: int = 1024):

        embeddings = OpenAIEmbeddings()

        index_name = "dbaerofaiss_from_langchain"
        # Список файлов для проверки
        files_to_check = [f'{index_name}.faiss', f'{index_name}.pkl']
        # Вызов функции проверки
        if check_files_exist(folder_path, files_to_check):
            # возможность загрузки предварительно сохраненной индексной базы с диска
            # Имя, используемое при сохранении файлов
            # Загрузка данных и создание нового экземпляра FAISS
            self.db = FAISS.load_local(
                folder_path=folder_path,
                embeddings=embeddings,
                index_name=index_name
            )

        else: # база не проиндексирована - сделать это с нуля
            # прочитать с гуглдрайва из под uvicorn не получилось из-за ssl ошибок.
            # простой запуск без uvicorn - сработывал нормально
            # document=getfilefromgoogledisk(uniquesubstringfromfilename='АЭРОПОРТОВ И АВИАЦИОННЫХ ТОВАРОПРОИЗВОДИТЕЛЕЙ')

            # чтение локальной копии файла базы знаний
            with open("Копия ПРАВИЛА СТРАХОВАНИЯ ОТВЕТСТВЕННОСТИ АЭРОПОРТОВ И АВИАЦИОННЫХ ТОВАРОПРОИЗВОДИТЕЛЕЙ.txt", "r", encoding="utf-8") as f:
                document = f.read()

            # создаем список чанков
            source_chunks = []
            splitter = CharacterTextSplitter(separator=sep, chunk_size=ch_size)
            for chunk in splitter.split_text(document):
                source_chunks.append(Document(page_content=chunk, metadata={}))

            # создаем индексную базу
            self.db = FAISS.from_documents(source_chunks, embeddings)
            # сохраняем db_from_texts на ваш гугл драйв
            self.db.save_local(folder_path=folder_path, index_name=index_name)        


    def get_answer(self,query: str = None, system: str = default_system):
        '''Функция получения ответа от chatgpt
        '''
        # релевантные отрезки из базы
        docs = self.db.similarity_search(query, k=4)
        message_content = '\n'.join([f'{doc.page_content}' for doc in docs])
        messages = [
            {"role": "system", "content": system},
            {"role": "user", "content": f"Ответь на вопрос клиента. Не упоминай документ с информацией для \
                                          ответа клиенту в ответе. Документ с информацией для ответа клиенту:\
                                          {message_content}\n\nВопрос клиента: \n{query}"}
        ]

        # получение ответа от chatgpt
        completion = openai.ChatCompletion.create(model="gpt-3.5-turbo",
                                                  messages=messages,
                                                  temperature=0)

        return completion.choices[0].message.content
# model = LLMModel("")
# Out:
# C:\temp\cacert-2024-03-11.pem
# C:\temp\apiopenaicom.pem

# %%
import runpy
import trace

# Создаем объект трассировки
tracer = trace.Trace(trace=True)

# Запускаем скрипт под трассировкой
tracer.run('runpy.run_path("model0.py")')
# Out:
#  --- modulename: runpy, funcname: run_path
# <frozen runpy>(277): <frozen runpy>(278): <frozen runpy>(279): <frozen runpy>(280): <frozen runpy>(281):  --- modulename: pkgutil, funcname: get_importer
# pkgutil.py(416):     path_item = os.fsdecode(path_item)
#  --- modulename: os, funcname: fsdecode
# <frozen os>(824): <frozen os>(825): <frozen os>(828): pkgutil.py(417):     try:
# pkgutil.py(418):         importer = sys.path_importer_cache[path_item]
# pkgutil.py(419):     except KeyError:
# pkgutil.py(420):         for path_hook in sys.path_hooks:
# pkgutil.py(421):             try:
# pkgutil.py(422):                 importer = path_hook(path_item)
#  --- modulename: zipimport, funcname: __init__
# <frozen zipimport>(65): <frozen zipimport>(67): <frozen zipimport>(69): <frozen zipimport>(70): <frozen zipimport>(72): <frozen zipimport>(73): <frozen zipimport>(74): <frozen zipimport>(75):  --- modulename: _bootstrap_external, funcname: _path_stat
# <frozen importlib._bootstrap_external>(147): <frozen zipimport>(86): <frozen zipimport>(89): <frozen zipimport>(91): <frozen zipimport>(92): <frozen zipimport>(93): <frozen zipimport>(94):  --- modulename: zipimport, funcname: _read_directory
# <frozen zipimport>(402): <frozen zipimport>(403): <frozen zipimport>(407): <frozen zipimport>(411): <frozen zipimport>(412): <frozen zipimport>(413): <frozen zipimport>(414): <frozen zipimport>(415): <frozen zipimport>(416): <frozen zipimport>(419): <frozen zipimport>(421): <frozen zipimport>(424): <frozen zipimport>(425): <frozen zipimport>(426): <frozen zipimport>(430): <frozen zipimport>(431): <frozen zipimport>(430): <frozen zipimport>(431): <frozen zipimport>(430): <frozen zipimport>(432): <frozen zipimport>(433): <frozen zipimport>(434): <frozen zipimport>(438): <frozen zipimport>(439): <frozen zipimport>(440): <frozen zipimport>(441): <frozen zipimport>(440): <frozen zipimport>(522): <frozen zipimport>(407): pkgutil.py(425):             except ImportError:
# pkgutil.py(426):                 pass
# pkgutil.py(420):         for path_hook in sys.path_hooks:
# pkgutil.py(421):             try:
# pkgutil.py(422):                 importer = path_hook(path_item)
#  --- modulename: _bootstrap_external, funcname: path_hook_for_FileFinder
# <frozen importlib._bootstrap_external>(1701):  --- modulename: _bootstrap_external, funcname: _path_isdir
# <frozen importlib._bootstrap_external>(166): <frozen importlib._bootstrap_external>(168):  --- modulename: _bootstrap_external, funcname: _path_is_mode_type
# <frozen importlib._bootstrap_external>(152): <frozen importlib._bootstrap_external>(153):  --- modulename: _bootstrap_external, funcname: _path_stat
# <frozen importlib._bootstrap_external>(147): <frozen importlib._bootstrap_external>(156): <frozen importlib._bootstrap_external>(1702): pkgutil.py(425):             except ImportError:
# pkgutil.py(426):                 pass
# pkgutil.py(420):         for path_hook in sys.path_hooks:
# pkgutil.py(428):             importer = None
# pkgutil.py(429):     return importer
# <frozen runpy>(283): <frozen runpy>(284): <frozen runpy>(287): <frozen runpy>(290):  --- modulename: runpy, funcname: _get_code_from_file
# <frozen runpy>(252): <frozen runpy>(253):  --- modulename: os, funcname: fsdecode
# <frozen os>(824): <frozen os>(825): <frozen os>(828):  --- modulename: ntpath, funcname: abspath
# <frozen ntpath>(572): <frozen ntpath>(573):  --- modulename: ntpath, funcname: normpath
# <frozen ntpath>(540): <frozen ntpath>(541): <frozen ntpath>(543): <frozen runpy>(254): <frozen runpy>(255):  --- modulename: pkgutil, funcname: read_code
# pkgutil.py(43):     import marshal
# pkgutil.py(45):     magic = stream.read(4)
# pkgutil.py(46):     if magic != importlib.util.MAGIC_NUMBER:
# pkgutil.py(47):         return None
# <frozen runpy>(254): <frozen runpy>(256): <frozen runpy>(258): <frozen runpy>(259): <frozen runpy>(258): <frozen runpy>(260): <frozen runpy>(291): <frozen runpy>(292): <frozen runpy>(291):  --- modulename: runpy, funcname: _run_module_code
# <frozen runpy>(95): <frozen runpy>(96):  --- modulename: runpy, funcname: __init__
# <frozen runpy>(29): <frozen runpy>(30): <frozen runpy>(31):  --- modulename: runpy, funcname: __enter__
# <frozen runpy>(34): <frozen runpy>(35): <frozen runpy>(36): <frozen runpy>(37): <frozen runpy>(38): <frozen runpy>(39): <frozen runpy>(40):  --- modulename: runpy, funcname: __init__
# <frozen runpy>(51): <frozen runpy>(52):  --- modulename: runpy, funcname: __enter__
# <frozen runpy>(55): <frozen runpy>(57): <frozen runpy>(58): <frozen runpy>(97): <frozen runpy>(98): <frozen runpy>(99): <frozen runpy>(98):  --- modulename: runpy, funcname: _run_code
# <frozen runpy>(69): <frozen runpy>(71): <frozen runpy>(72): <frozen runpy>(73): <frozen runpy>(74): <frozen runpy>(81): <frozen runpy>(82): <frozen runpy>(83): <frozen runpy>(84): <frozen runpy>(85): <frozen runpy>(86): <frozen runpy>(87): <frozen runpy>(81): <frozen runpy>(88):  --- modulename: model0, funcname: <module>
# model0.py(1): from dotenv import load_dotenv
#  --- modulename: _bootstrap, funcname: _handle_fromlist
# <frozen importlib._bootstrap>(1217): <frozen importlib._bootstrap>(1218): <frozen importlib._bootstrap>(1225): <frozen importlib._bootstrap>(1229): <frozen importlib._bootstrap>(1217): <frozen importlib._bootstrap>(1241): model0.py(2): import os
# model0.py(3): os.environ.clear()
#  --- modulename: _collections_abc, funcname: clear
# <frozen _collections_abc>(935): <frozen _collections_abc>(936): <frozen _collections_abc>(937):  --- modulename: _collections_abc, funcname: popitem
# <frozen _collections_abc>(925): <frozen _collections_abc>(926):  --- modulename: os, funcname: __iter__
# <frozen os>(699): <frozen os>(700): <frozen os>(701):  --- modulename: os, funcname: __iter__
# <frozen _collections_abc>(929):  --- modulename: os, funcname: __getitem__
# <frozen os>(675): <frozen os>(676):  --- modulename: os, funcname: encodekey
# <frozen os>(749):  --- modulename: os, funcname: check_str
# <frozen os>(743): <frozen os>(745): <frozen os>(680): <frozen _collections_abc>(930):  --- modulename: os, funcname: __delitem__
# <frozen os>(689):  --- modulename: os, funcname: encodekey
# <frozen os>(749):  --- modulename: os, funcname: check_str
# <frozen os>(743): <frozen os>(745): <frozen os>(690): <frozen os>(691): <frozen os>(692): <frozen _collections_abc>(931): <frozen _collections_abc>(936): <frozen _collections_abc>(937):  --- modulename: _collections_abc, funcname: popitem
# <frozen _collections_abc>(925): <frozen _collections_abc>(926):  --- modulename: os, funcname: __iter__
# <frozen os>(699): <frozen os>(700): <frozen os>(701):  --- modulename: os, funcname: __iter__
# <frozen _collections_abc>(929):  --- modulename: os, funcname: __getitem__
# <frozen os>(675): <frozen os>(676):  --- modulename: os, funcname: encodekey
# <frozen os>(749):  --- modulename: os, funcname: check_str
# <frozen os>(743): <frozen os>(745): <frozen os>(680): <frozen _collections_abc>(930):  --- modulename: os, funcname: __delitem__
# <frozen os>(689):  --- modulename: os, funcname: encodekey
# <frozen os>(749):  --- modulename: os, funcname: check_str
# <frozen os>(743): <frozen os>(745): <frozen os>(690): <frozen os>(691): <frozen os>(692): <frozen _collections_abc>(931): <frozen _collections_abc>(936): <frozen _collections_abc>(937):  --- modulename: _collections_abc, funcname: popitem
# <frozen _collections_abc>(925): <frozen _collections_abc>(926):  --- modulename: os, funcname: __iter__
# <frozen os>(699): <frozen os>(700): <frozen os>(701):  --- modulename: os, funcname: __iter__
# <frozen _collections_abc>(929):  --- modulename: os, funcname: __getitem__
# <frozen os>(675): <frozen os>(676):  --- modulename: os, funcname: encodekey
# <frozen os>(749):  --- modulename: os, funcname: check_str
# <frozen os>(743): <frozen os>(745): <frozen os>(680): <frozen _collections_abc>(930):  --- modulename: os, funcname: __delitem__
# <frozen os>(689):  --- modulename: os, funcname: encodekey
# <frozen os>(749):  --- modulename: os, funcname: check_str
# <frozen os>(743): <frozen os>(745): <frozen os>(690): <frozen os>(691): <frozen os>(692): <frozen _collections_abc>(931): <frozen _collections_abc>(936): <frozen _collections_abc>(937):  --- modulename: _collections_abc, funcname: popitem
# <frozen _collections_abc>(925): <frozen _collections_abc>(926):  --- modulename: os, funcname: __iter__
# <frozen os>(699): <frozen os>(700): <frozen _collections_abc>(927): <frozen _collections_abc>(928): <frozen _collections_abc>(938): <frozen _collections_abc>(939): model0.py(4): load_dotenv(".env")
#  --- modulename: main, funcname: load_dotenv
# main.py(345):     if dotenv_path is None and stream is None:
# main.py(348):     dotenv = DotEnv(
# main.py(349):         dotenv_path=dotenv_path,
# main.py(350):         stream=stream,
# main.py(351):         verbose=verbose,
# main.py(352):         interpolate=interpolate,
# main.py(353):         override=override,
# main.py(354):         encoding=encoding,
# main.py(348):     dotenv = DotEnv(
#  --- modulename: main, funcname: __init__
# main.py(45):         self.dotenv_path: Optional[StrPath] = dotenv_path
# main.py(46):         self.stream: Optional[IO[str]] = stream
# main.py(47):         self._dict: Optional[Dict[str, Optional[str]]] = None
# main.py(48):         self.verbose: bool = verbose
# main.py(49):         self.encoding: Optional[str] = encoding
# main.py(50):         self.interpolate: bool = interpolate
# main.py(51):         self.override: bool = override
# main.py(356):     return dotenv.set_as_environment_variables()
#  --- modulename: main, funcname: set_as_environment_variables
# main.py(92):         if not self.dict():
#  --- modulename: main, funcname: dict
# main.py(70):         if self._dict:
# main.py(73):         raw_values = self.parse()
# main.py(75):         if self.interpolate:
# main.py(76):             self._dict = OrderedDict(resolve_variables(raw_values, override=self.override))
#  --- modulename: main, funcname: resolve_variables
# main.py(236):     new_values: Dict[str, Optional[str]] = {}
# main.py(238):     for (name, value) in values:
#  --- modulename: main, funcname: parse
# main.py(83):         with self._get_stream() as stream:
#  --- modulename: contextlib, funcname: helper
# contextlib.py(301):         return _GeneratorContextManager(func, args, kwds)
#  --- modulename: contextlib, funcname: __init__
# contextlib.py(105):         self.gen = func(*args, **kwds)
# contextlib.py(106):         self.func, self.args, self.kwds = func, args, kwds
# contextlib.py(108):         doc = getattr(func, "__doc__", None)
# contextlib.py(109):         if doc is None:
# contextlib.py(110):             doc = type(self).__doc__
# contextlib.py(111):         self.__doc__ = doc
#  --- modulename: contextlib, funcname: __enter__
# contextlib.py(135):         del self.args, self.kwds, self.func
# contextlib.py(136):         try:
# contextlib.py(137):             return next(self.gen)
#  --- modulename: main, funcname: _get_stream
# main.py(55):         if self.dotenv_path and os.path.isfile(self.dotenv_path):
#  --- modulename: genericpath, funcname: isfile
# <frozen genericpath>(29): <frozen genericpath>(30): <frozen genericpath>(33): main.py(56):             with open(self.dotenv_path, encoding=self.encoding) as stream:
#  --- modulename: codecs, funcname: __init__
# <frozen codecs>(310):  --- modulename: codecs, funcname: __init__
# <frozen codecs>(268): <frozen codecs>(312): main.py(57):                 yield stream
# main.py(84):             for mapping in with_warn_for_invalid_lines(parse_stream(stream)):
#  --- modulename: main, funcname: with_warn_for_invalid_lines
# main.py(26):     for mapping in mappings:
#  --- modulename: parser, funcname: parse_stream
# parser.py(173):     reader = Reader(stream)
#  --- modulename: parser, funcname: __init__
# parser.py(64):         self.string = stream.read()
#  --- modulename: codecs, funcname: decode
# <frozen codecs>(321): <frozen codecs>(322): <frozen codecs>(324): <frozen codecs>(325): parser.py(65):         self.position = Position.start()
#  --- modulename: parser, funcname: start
# parser.py(47):         return cls(chars=0, line=1)
#  --- modulename: parser, funcname: __init__
# parser.py(42):         self.chars = chars
# parser.py(43):         self.line = line
# parser.py(66):         self.mark = Position.start()
#  --- modulename: parser, funcname: start
# parser.py(47):         return cls(chars=0, line=1)
#  --- modulename: parser, funcname: __init__
# parser.py(42):         self.chars = chars
# parser.py(43):         self.line = line
# parser.py(174):     while reader.has_next():
#  --- modulename: parser, funcname: has_next
# parser.py(69):         return self.position.chars < len(self.string)
# parser.py(175):         yield parse_binding(reader)
#  --- modulename: parser, funcname: parse_binding
# parser.py(136):     reader.set_mark()
#  --- modulename: parser, funcname: set_mark
# parser.py(72):         self.mark.set(self.position)
#  --- modulename: parser, funcname: set
# parser.py(50):         self.chars = other.chars
# parser.py(51):         self.line = other.line
# parser.py(137):     try:
# parser.py(138):         reader.read_regex(_multiline_whitespace)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(139):         if not reader.has_next():
#  --- modulename: parser, funcname: has_next
# parser.py(69):         return self.position.chars < len(self.string)
# parser.py(146):         reader.read_regex(_export)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(147):         key = parse_key(reader)
#  --- modulename: parser, funcname: parse_key
# parser.py(106):     char = reader.peek(1)
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(107):     if char == "#":
# parser.py(109):     elif char == "'":
# parser.py(112):         (key,) = reader.read_regex(_unquoted_key)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(113):     return key
# parser.py(148):         reader.read_regex(_whitespace)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(149):         if reader.peek(1) == "=":
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(150):             reader.read_regex(_equal_sign)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(151):             value: Optional[str] = parse_value(reader)
#  --- modulename: parser, funcname: parse_value
# parser.py(122):     char = reader.peek(1)
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(123):     if char == u"'":
# parser.py(126):     elif char == u'"':
# parser.py(129):     elif char in (u"", u"\n", u"\r"):
# parser.py(132):         return parse_unquoted_value(reader)
#  --- modulename: parser, funcname: parse_unquoted_value
# parser.py(117):     (part,) = reader.read_regex(_unquoted_value)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(118):     return re.sub(r"\s+#.*", "", part).rstrip()
#  --- modulename: __init__, funcname: sub
# __init__.py(185):     return _compile(pattern, flags).sub(repl, string, count)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# parser.py(154):         reader.read_regex(_comment)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(155):         reader.read_regex(_end_of_line)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(156):         return Binding(
# parser.py(157):             key=key,
# parser.py(158):             value=value,
# parser.py(159):             original=reader.get_marked(),
#  --- modulename: parser, funcname: get_marked
# parser.py(75):         return Original(
# parser.py(76):             string=self.string[self.mark.chars:self.position.chars],
# parser.py(77):             line=self.mark.line,
# parser.py(75):         return Original(
# parser.py(160):             error=False,
# parser.py(156):         return Binding(
# main.py(27):         if mapping.error:
# main.py(32):         yield mapping
# main.py(85):                 if mapping.key is not None:
# main.py(86):                     yield mapping.key, mapping.value
# main.py(239):         if value is None:
# main.py(242):             atoms = parse_variables(value)
# main.py(243):             env: Dict[str, Optional[str]] = {}
# main.py(244):             if override:
# main.py(248):                 env.update(new_values)
# main.py(249):                 env.update(os.environ)  # type: ignore
#  --- modulename: _collections_abc, funcname: keys
# <frozen _collections_abc>(788):  --- modulename: _collections_abc, funcname: __init__
# <frozen _collections_abc>(813):  --- modulename: _collections_abc, funcname: __iter__
# <frozen _collections_abc>(836):  --- modulename: os, funcname: __iter__
# <frozen os>(699): <frozen os>(700): main.py(250):             result = "".join(atom.resolve(env) for atom in atoms)
#  --- modulename: main, funcname: <genexpr>
# main.py(250):             result = "".join(atom.resolve(env) for atom in atoms)
#  --- modulename: variables, funcname: parse_variables
# variables.py(71):     cursor = 0
# variables.py(73):     for match in _posix_variable.finditer(value):
# variables.py(84):     length = len(value)
# variables.py(85):     if cursor < length:
# variables.py(86):         yield Literal(value=value[cursor:length])
#  --- modulename: variables, funcname: __init__
# variables.py(31):         self.value = value
#  --- modulename: variables, funcname: resolve
# variables.py(45):         return self.value
#  --- modulename: main, funcname: <genexpr>
# main.py(250):             result = "".join(atom.resolve(env) for atom in atoms)
#  --- modulename: variables, funcname: parse_variables
# main.py(252):         new_values[name] = result
# main.py(238):     for (name, value) in values:
#  --- modulename: main, funcname: parse
# main.py(84):             for mapping in with_warn_for_invalid_lines(parse_stream(stream)):
#  --- modulename: main, funcname: with_warn_for_invalid_lines
# main.py(26):     for mapping in mappings:
#  --- modulename: parser, funcname: parse_stream
# parser.py(174):     while reader.has_next():
#  --- modulename: parser, funcname: has_next
# parser.py(69):         return self.position.chars < len(self.string)
# parser.py(175):         yield parse_binding(reader)
#  --- modulename: parser, funcname: parse_binding
# parser.py(136):     reader.set_mark()
#  --- modulename: parser, funcname: set_mark
# parser.py(72):         self.mark.set(self.position)
#  --- modulename: parser, funcname: set
# parser.py(50):         self.chars = other.chars
# parser.py(51):         self.line = other.line
# parser.py(137):     try:
# parser.py(138):         reader.read_regex(_multiline_whitespace)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(139):         if not reader.has_next():
#  --- modulename: parser, funcname: has_next
# parser.py(69):         return self.position.chars < len(self.string)
# parser.py(146):         reader.read_regex(_export)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(147):         key = parse_key(reader)
#  --- modulename: parser, funcname: parse_key
# parser.py(106):     char = reader.peek(1)
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(107):     if char == "#":
# parser.py(109):     elif char == "'":
# parser.py(112):         (key,) = reader.read_regex(_unquoted_key)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(113):     return key
# parser.py(148):         reader.read_regex(_whitespace)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(149):         if reader.peek(1) == "=":
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(150):             reader.read_regex(_equal_sign)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(151):             value: Optional[str] = parse_value(reader)
#  --- modulename: parser, funcname: parse_value
# parser.py(122):     char = reader.peek(1)
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(123):     if char == u"'":
# parser.py(126):     elif char == u'"':
# parser.py(129):     elif char in (u"", u"\n", u"\r"):
# parser.py(132):         return parse_unquoted_value(reader)
#  --- modulename: parser, funcname: parse_unquoted_value
# parser.py(117):     (part,) = reader.read_regex(_unquoted_value)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(118):     return re.sub(r"\s+#.*", "", part).rstrip()
#  --- modulename: __init__, funcname: sub
# __init__.py(185):     return _compile(pattern, flags).sub(repl, string, count)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# parser.py(154):         reader.read_regex(_comment)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(155):         reader.read_regex(_end_of_line)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(156):         return Binding(
# parser.py(157):             key=key,
# parser.py(158):             value=value,
# parser.py(159):             original=reader.get_marked(),
#  --- modulename: parser, funcname: get_marked
# parser.py(75):         return Original(
# parser.py(76):             string=self.string[self.mark.chars:self.position.chars],
# parser.py(77):             line=self.mark.line,
# parser.py(75):         return Original(
# parser.py(160):             error=False,
# parser.py(156):         return Binding(
# main.py(27):         if mapping.error:
# main.py(32):         yield mapping
# main.py(85):                 if mapping.key is not None:
# main.py(86):                     yield mapping.key, mapping.value
# main.py(239):         if value is None:
# main.py(242):             atoms = parse_variables(value)
# main.py(243):             env: Dict[str, Optional[str]] = {}
# main.py(244):             if override:
# main.py(248):                 env.update(new_values)
# main.py(249):                 env.update(os.environ)  # type: ignore
#  --- modulename: _collections_abc, funcname: keys
# <frozen _collections_abc>(788):  --- modulename: _collections_abc, funcname: __init__
# <frozen _collections_abc>(813):  --- modulename: _collections_abc, funcname: __iter__
# <frozen _collections_abc>(836):  --- modulename: os, funcname: __iter__
# <frozen os>(699): <frozen os>(700): main.py(250):             result = "".join(atom.resolve(env) for atom in atoms)
#  --- modulename: main, funcname: <genexpr>
# main.py(250):             result = "".join(atom.resolve(env) for atom in atoms)
#  --- modulename: variables, funcname: parse_variables
# variables.py(71):     cursor = 0
# variables.py(73):     for match in _posix_variable.finditer(value):
# variables.py(84):     length = len(value)
# variables.py(85):     if cursor < length:
# variables.py(86):         yield Literal(value=value[cursor:length])
#  --- modulename: variables, funcname: __init__
# variables.py(31):         self.value = value
#  --- modulename: variables, funcname: resolve
# variables.py(45):         return self.value
#  --- modulename: main, funcname: <genexpr>
# main.py(250):             result = "".join(atom.resolve(env) for atom in atoms)
#  --- modulename: variables, funcname: parse_variables
# main.py(252):         new_values[name] = result
# main.py(238):     for (name, value) in values:
#  --- modulename: main, funcname: parse
# main.py(84):             for mapping in with_warn_for_invalid_lines(parse_stream(stream)):
#  --- modulename: main, funcname: with_warn_for_invalid_lines
# main.py(26):     for mapping in mappings:
#  --- modulename: parser, funcname: parse_stream
# parser.py(174):     while reader.has_next():
#  --- modulename: parser, funcname: has_next
# parser.py(69):         return self.position.chars < len(self.string)
# parser.py(175):         yield parse_binding(reader)
#  --- modulename: parser, funcname: parse_binding
# parser.py(136):     reader.set_mark()
#  --- modulename: parser, funcname: set_mark
# parser.py(72):         self.mark.set(self.position)
#  --- modulename: parser, funcname: set
# parser.py(50):         self.chars = other.chars
# parser.py(51):         self.line = other.line
# parser.py(137):     try:
# parser.py(138):         reader.read_regex(_multiline_whitespace)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(139):         if not reader.has_next():
#  --- modulename: parser, funcname: has_next
# parser.py(69):         return self.position.chars < len(self.string)
# parser.py(146):         reader.read_regex(_export)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(147):         key = parse_key(reader)
#  --- modulename: parser, funcname: parse_key
# parser.py(106):     char = reader.peek(1)
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(107):     if char == "#":
# parser.py(109):     elif char == "'":
# parser.py(112):         (key,) = reader.read_regex(_unquoted_key)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(113):     return key
# parser.py(148):         reader.read_regex(_whitespace)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(149):         if reader.peek(1) == "=":
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(150):             reader.read_regex(_equal_sign)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(151):             value: Optional[str] = parse_value(reader)
#  --- modulename: parser, funcname: parse_value
# parser.py(122):     char = reader.peek(1)
#  --- modulename: parser, funcname: peek
# parser.py(81):         return self.string[self.position.chars:self.position.chars + count]
# parser.py(123):     if char == u"'":
# parser.py(126):     elif char == u'"':
# parser.py(129):     elif char in (u"", u"\n", u"\r"):
# parser.py(132):         return parse_unquoted_value(reader)
#  --- modulename: parser, funcname: parse_unquoted_value
# parser.py(117):     (part,) = reader.read_regex(_unquoted_value)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(118):     return re.sub(r"\s+#.*", "", part).rstrip()
#  --- modulename: __init__, funcname: sub
# __init__.py(185):     return _compile(pattern, flags).sub(repl, string, count)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# parser.py(154):         reader.read_regex(_comment)
#  --- modulename: parser, funcname: read_regex
# parser.py(91):         match = regex.match(self.string, self.position.chars)
# parser.py(92):         if match is None:
# parser.py(94):         self.position.advance(self.string[match.start():match.end()])
#  --- modulename: parser, funcname: advance
# parser.py(54):         self.chars += len(string)
# parser.py(55):         self.line += len(re.findall(_newline, string))
#  --- modulename: __init__, funcname: findall
# __init__.py(216):     return _compile(pattern, flags).findall(string)
#  --- modulename: __init__, funcname: _compile
# __init__.py(274):     if isinstance(flags, RegexFlag):
# __init__.py(276):     try:
# __init__.py(277):         return _cache[type(pattern), pattern, flags]
# __init__.py(278):     except KeyError:
# __init__.py(279):         pass
# __init__.py(280):     if isinstance(pattern, Pattern):
# __init__.py(281):         if flags:
# __init__.py(284):         return pattern
# parser.py(95):         return match.groups()
# parser.py(155):         reader.read_regex(_end_of_line)
#  --- modulename: parser, funcname: read_regex
# ...
# pathlib.py(542):             self._str = self._format_parsed_parts(self._drv, self._root,
#  --- modulename: pathlib, funcname: _format_parsed_parts
# pathlib.py(525):         if drv or root:
# pathlib.py(526):             return drv + root + cls._flavour.join(parts[1:])
# pathlib.py(544):             return self._str
# pathlib.py(1243):         return True
# _config.py(119):             ca_bundle_path = Path(self.verify)
#  --- modulename: pathlib, funcname: __new__
# pathlib.py(869):         if cls is Path:
# pathlib.py(870):             cls = WindowsPath if os.name == 'nt' else PosixPath
# pathlib.py(871):         self = cls._from_parts(args)
#  --- modulename: pathlib, funcname: _from_parts
# pathlib.py(508):         self = object.__new__(cls)
# pathlib.py(509):         drv, root, parts = self._parse_args(args)
#  --- modulename: pathlib, funcname: _parse_args
# pathlib.py(488):         parts = []
# pathlib.py(489):         for a in args:
# pathlib.py(490):             if isinstance(a, PurePath):
# pathlib.py(493):                 a = os.fspath(a)
# pathlib.py(494):                 if isinstance(a, str):
# pathlib.py(496):                     parts.append(str(a))
# pathlib.py(489):         for a in args:
# pathlib.py(502):         return cls._flavour.parse_parts(parts)
#  --- modulename: pathlib, funcname: parse_parts
# pathlib.py(57):         parsed = []
# pathlib.py(58):         sep = self.sep
# pathlib.py(59):         altsep = self.altsep
# pathlib.py(60):         drv = root = ''
# pathlib.py(61):         it = reversed(parts)
# pathlib.py(62):         for part in it:
# pathlib.py(63):             if not part:
# pathlib.py(65):             if altsep:
# pathlib.py(66):                 part = part.replace(altsep, sep)
# pathlib.py(67):             drv, root, rel = self.splitroot(part)
#  --- modulename: pathlib, funcname: splitroot
# pathlib.py(148):         first = part[0:1]
# pathlib.py(149):         second = part[1:2]
# pathlib.py(150):         if (second == sep and first == sep):
# pathlib.py(157):             prefix = ''
# pathlib.py(158):         third = part[2:3]
# pathlib.py(159):         if (second == sep and first == sep and third != sep):
# pathlib.py(176):         drv = root = ''
# pathlib.py(177):         if second == ':' and first in self.drive_letters:
# pathlib.py(178):             drv = part[:2]
# pathlib.py(179):             part = part[2:]
# pathlib.py(180):             first = third
# pathlib.py(181):         if first == sep:
# pathlib.py(182):             root = first
# pathlib.py(183):             part = part.lstrip(sep)
# pathlib.py(184):         return prefix + drv, root, part
# pathlib.py(68):             if sep in rel:
# pathlib.py(69):                 for x in reversed(rel.split(sep)):
# pathlib.py(70):                     if x and x != '.':
# pathlib.py(71):                         parsed.append(sys.intern(x))
# pathlib.py(69):                 for x in reversed(rel.split(sep)):
# pathlib.py(70):                     if x and x != '.':
# pathlib.py(71):                         parsed.append(sys.intern(x))
# pathlib.py(69):                 for x in reversed(rel.split(sep)):
# pathlib.py(75):             if drv or root:
# pathlib.py(76):                 if not drv:
# pathlib.py(88):                 break
# pathlib.py(89):         if drv or root:
# pathlib.py(90):             parsed.append(drv + root)
# pathlib.py(91):         parsed.reverse()
# pathlib.py(92):         return drv, root, parsed
# pathlib.py(510):         self._drv = drv
# pathlib.py(511):         self._root = root
# pathlib.py(512):         self._parts = parts
# pathlib.py(513):         return self
# pathlib.py(872):         if not self._flavour.is_supported:
# pathlib.py(875):         return self
# _config.py(126):         context = self._create_default_ssl_context()
#  --- modulename: _config, funcname: _create_default_ssl_context
# _config.py(162):         context = ssl.SSLContext(ssl.PROTOCOL_TLS_CLIENT)
#  --- modulename: ssl, funcname: __new__
# ssl.py(493):         if protocol is None:
# ssl.py(500):         self = _SSLContext.__new__(cls, protocol)
# main.py(1101):         except (ValueError, TypeError, AssertionError) as exc:
# model0.py(54):         with patch('httpx._config.create_ssl_context', new=patched_create_ssl_context):
#  --- modulename: mock, funcname: __exit__
# mock.py(1573):         if self.is_local and self.temp_original is not DEFAULT:
# mock.py(1574):             setattr(self.target, self.attribute, self.temp_original)
# mock.py(1584):         del self.temp_original
# mock.py(1585):         del self.is_local
# mock.py(1586):         del self.target
# mock.py(1587):         exit_stack = self._exit_stack
# mock.py(1588):         del self._exit_stack
# mock.py(1589):         return exit_stack.__exit__(*exc_info)
#  --- modulename: contextlib, funcname: __exit__
# contextlib.py(559):         received_exc = exc_details[0] is not None
# contextlib.py(563):         frame_exc = sys.exc_info()[1]
# contextlib.py(564):         def _fix_exception_context(new_exc, old_exc):
# contextlib.py(580):         suppressed_exc = False
# contextlib.py(581):         pending_raise = False
# contextlib.py(582):         while self._exit_callbacks:
# contextlib.py(596):         if pending_raise:
# contextlib.py(605):         return received_exc and suppressed_exc
# <frozen runpy>(96):  --- modulename: runpy, funcname: __exit__
# <frozen runpy>(61): <frozen runpy>(62): <frozen runpy>(96):  --- modulename: runpy, funcname: __exit__
# <frozen runpy>(43): <frozen runpy>(46): <frozen runpy>(47): garbage.py(48):             if msg == b'DIE':
# garbage.py(50):             fmt = 'L' if len(msg) == 4 else 'Q'
# garbage.py(51):             key = struct.unpack(fmt, msg)[0]
# garbage.py(52):             tup = self.gc.refs.pop(key, None)
# garbage.py(53):             if tup and tup.event:
# garbage.py(55):             del tup
# garbage.py(43):         while True:
# garbage.py(45):             if getpid is None or getpid() != self.pid:
# garbage.py(47):             msg = s.recv()
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# Cell In[8], line 8
#       5 tracer = trace.Trace(trace=True)
#       7 # Запускаем скрипт под трассировкой
# ----> 8 tracer.run('runpy.run_path("model0.py")')
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\trace.py:441, in Trace.run(self, cmd)
#     439 import __main__
#     440 dict = __main__.__dict__
# --> 441 self.runctx(cmd, dict, dict)
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\trace.py:450, in Trace.runctx(self, cmd, globals, locals)
#     448     sys.settrace(self.globaltrace)
#     449 try:
# --> 450     exec(cmd, globals, locals)
#     451 finally:
#     452     if not self.donothing:
#
# File <string>:1
#
# File <frozen runpy>:291, in run_path(path_name, init_globals, run_name)
#
# File <frozen runpy>:98, in _run_module_code(code, init_globals, mod_name, mod_spec, pkg_name, script_name)
#
# File <frozen runpy>:88, in _run_code(code, run_globals, init_globals, mod_name, mod_spec, pkg_name, script_name)
#
# File c:\Users\v.volkov\Documents\GitHub\WebServiceFastAPI\Занятие 11\model0.py:115
#     109         completion = openai.ChatCompletion.create(model="gpt-3.5-turbo",
#     110                                                   messages=messages,
#     111                                                   temperature=0)
#     113         return completion.choices[0].message.content
# --> 115 model = LLMModel("")
#
# File c:\Users\v.volkov\Documents\GitHub\WebServiceFastAPI\Занятие 11\model0.py:58, in LLMModel.__init__(self, folder_path, sep, ch_size)
#      56 print(dir(OpenAIEmbeddings))
#      57 print(OpenAIEmbeddings.__doc__)
# ---> 58 embeddings = OpenAIEmbeddings()
#      60 index_name = "dbaerofaiss_from_langchain"
#      61 # Список файлов для проверки
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\pydantic\v1\main.py:339, in BaseModel.__init__(__pydantic_self__, **data)
#     333 """
#     334 Create a new model by parsing and validating input data from keyword arguments.
#     335
#     336 Raises ValidationError if the input data cannot be parsed to form a valid model.
#     337 """
#     338 # Uses something other than `self` the first arg to allow "self" as a settable attribute
# --> 339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
#     341     raise validation_error
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\pydantic\v1\main.py:1100, in validate_model(model, input_data, cls)
#    1098     continue
#    1099 try:
# -> 1100     values = validator(cls_, values)
#    1101 except (ValueError, TypeError, AssertionError) as exc:
#    1102     errors.append(ErrorWrapper(exc, loc=ROOT_KEY))
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\langchain_openai\embeddings\base.py:232, in OpenAIEmbeddings.validate_environment(cls, values)
#     230 if not values.get("client"):
#     231     sync_specific = {"http_client": values["http_client"]}
# --> 232     values["client"] = openai.OpenAI(
#     233         **client_params, **sync_specific
#     234     ).embeddings
#     235 if not values.get("async_client"):
#     236     async_specific = {"http_client": values["http_async_client"]}
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\openai\_client.py:122, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     119 if base_url is None:
#     120     base_url = f"https://api.openai.com/v1"
# --> 122 super().__init__(
#     123     version=__version__,
#     124     base_url=base_url,
#     125     max_retries=max_retries,
#     126     timeout=timeout,
#     127     http_client=http_client,
#     128     custom_headers=default_headers,
#     129     custom_query=default_query,
#     130     _strict_response_validation=_strict_response_validation,
#     131 )
#     133 self._default_stream_cls = Stream
#     135 self.completions = resources.Completions(self)
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\openai\_base_client.py:825, in SyncAPIClient.__init__(self, version, base_url, max_retries, timeout, transport, proxies, limits, http_client, custom_headers, custom_query, _strict_response_validation)
#     808     raise TypeError(
#     809         f"Invalid `http_client` argument; Expected an instance of `httpx.Client` but got {type(http_client)}"
#     810     )
#     812 super().__init__(
#     813     version=version,
#     814     limits=limits,
#    (...)
#     823     _strict_response_validation=_strict_response_validation,
#     824 )
# --> 825 self._client = http_client or SyncHttpxClientWrapper(
#     826     base_url=base_url,
#     827     # cast to a valid type because mypy doesn't understand our type narrowing
#     828     timeout=cast(Timeout, timeout),
#     829     proxies=proxies,
#     830     transport=transport,
#     831     limits=limits,
#     832     follow_redirects=True,
#     833 )
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\openai\_base_client.py:723, in _DefaultHttpxClient.__init__(self, **kwargs)
#     721 kwargs.setdefault("limits", DEFAULT_CONNECTION_LIMITS)
#     722 kwargs.setdefault("follow_redirects", True)
# --> 723 super().__init__(**kwargs)
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\httpx\_client.py:685, in Client.__init__(self, auth, params, headers, cookies, verify, cert, http1, http2, proxy, proxies, mounts, timeout, follow_redirects, limits, max_redirects, event_hooks, base_url, transport, app, trust_env, default_encoding)
#     682 allow_env_proxies = trust_env and app is None and transport is None
#     683 proxy_map = self._get_proxy_map(proxies or proxy, allow_env_proxies)
# --> 685 self._transport = self._init_transport(
#     686     verify=verify,
#     687     cert=cert,
#     688     http1=http1,
#     689     http2=http2,
#     690     limits=limits,
#     691     transport=transport,
#     692     app=app,
#     693     trust_env=trust_env,
#     694 )
#     695 self._mounts: dict[URLPattern, BaseTransport | None] = {
#     696     URLPattern(key): None
#     697     if proxy is None
#    (...)
#     707     for key, proxy in proxy_map.items()
#     708 }
#     709 if mounts is not None:
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\httpx\_client.py:733, in Client._init_transport(self, verify, cert, http1, http2, limits, transport, app, trust_env)
#     730 if app is not None:
#     731     return WSGITransport(app=app)
# --> 733 return HTTPTransport(
#     734     verify=verify,
#     735     cert=cert,
#     736     http1=http1,
#     737     http2=http2,
#     738     limits=limits,
#     739     trust_env=trust_env,
#     740 )
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\httpx\_transports\default.py:136, in HTTPTransport.__init__(self, verify, cert, http1, http2, limits, trust_env, proxy, uds, local_address, retries, socket_options)
#     122 def __init__(
#     123     self,
#     124     verify: VerifyTypes = True,
#    (...)
#     134     socket_options: typing.Iterable[SOCKET_OPTION] | None = None,
#     135 ) -> None:
# --> 136     ssl_context = create_ssl_context(verify=verify, cert=cert, trust_env=trust_env)
#     137     proxy = Proxy(url=proxy) if isinstance(proxy, (str, URL)) else proxy
#     139     if proxy is None:
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\httpx\_config.py:53, in create_ssl_context(cert, verify, trust_env, http2)
#      47 def create_ssl_context(
#      48     cert: CertTypes | None = None,
#      49     verify: VerifyTypes = True,
#      50     trust_env: bool = True,
#      51     http2: bool = False,
#      52 ) -> ssl.SSLContext:
# ---> 53     return SSLConfig(
#      54         cert=cert, verify=verify, trust_env=trust_env, http2=http2
#      55     ).ssl_context
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\httpx\_config.py:77, in SSLConfig.__init__(self, cert, verify, trust_env, http2)
#      75 self.trust_env = trust_env
#      76 self.http2 = http2
# ---> 77 self.ssl_context = self.load_ssl_context()
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\httpx\_config.py:89, in SSLConfig.load_ssl_context(self)
#      80 logger.debug(
#      81     "load_ssl_context verify=%r cert=%r trust_env=%r http2=%r",
#      82     self.verify,
#    (...)
#      85     self.http2,
#      86 )
#      88 if self.verify:
# ---> 89     return self.load_ssl_context_verify()
#      90 return self.load_ssl_context_no_verify()
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\httpx\_config.py:126, in SSLConfig.load_ssl_context_verify(self)
#     120 else:
#     121     raise IOError(
#     122         "Could not find a suitable TLS CA certificate bundle, "
#     123         "invalid path: {}".format(self.verify)
#     124     )
# --> 126 context = self._create_default_ssl_context()
#     127 context.verify_mode = ssl.CERT_REQUIRED
#     128 context.check_hostname = True
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\site-packages\httpx\_config.py:162, in SSLConfig._create_default_ssl_context(self)
#     157 def _create_default_ssl_context(self) -> ssl.SSLContext:
#     158     """
#     159     Creates the default SSLContext object that's used for both verified
#     160     and unverified connections.
#     161     """
# --> 162     context = ssl.SSLContext(ssl.PROTOCOL_TLS_CLIENT)
#     163     set_minimum_tls_version_1_2(context)
#     164     context.options |= ssl.OP_NO_COMPRESSION
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3119\Lib\ssl.py:500, in SSLContext.__new__(cls, protocol, *args, **kwargs)
#     494     warnings.warn(
#     495         "ssl.SSLContext() without protocol argument is deprecated.",
#     496         category=DeprecationWarning,
#     497         stacklevel=2
#     498     )
#     499     protocol = PROTOCOL_TLS
# --> 500 self = _SSLContext.__new__(cls, protocol)
#     501 return self
#
# SSLError: [SSL] unknown error (_ssl.c:3098)

# %%
# from model0 import LLMModel
model = LLMModel("")

# %%
q1="какая деятельность относится к аэропортовой"
model.get_answer(q1)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\connection.py:200, in HTTPConnection._new_conn(self)
#     199 try:
# --> 200     sock = connection.create_connection(
#     201         (self._dns_host, self.port),
#     202         self.timeout,
#     203         source_address=self.source_address,
#     204         socket_options=self.socket_options,
#     205     )
#     206 except socket.gaierror as e:
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# --> 954 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\connection.py:604, in HTTPSConnection.connect(self)
#     603 sock: socket.socket | ssl.SSLSocket
# --> 604 self.sock = sock = self._new_conn()
#     605 server_hostname: str = self.host
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\connection.py:207, in HTTPConnection._new_conn(self)
#     206 except socket.gaierror as e:
# --> 207     raise NameResolutionError(self.host, self, e) from e
#     208 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x000002762777B1C0>: Failed to resolve 'openaipublic.blob.core.windows.net' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File C:\Users\v.volkov\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='openaipublic.blob.core.windows.net', port=443): Max retries exceeded with url: /encodings/cl100k_base.tiktoken (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002762777B1C0>: Failed to resolve 'openaipublic.blob.core.windows.net' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 2
#       1 q1="какая деятельность относится к аэропортовой"
# ----> 2 model.get_answer(q1)
#
# Cell In[1], line 93, in LLMModel.get_answer(self, query, system)
#      90 '''Функция получения ответа от chatgpt
#      91 '''
#      92 # релевантные отрезки из базы
# ---> 93 docs = self.db.similarity_search(query, k=4)
#      94 message_content = '\n'.join([f'{doc.page_content}' for doc in docs])
#      95 messages = [
#      96     {"role": "system", "content": system},
#      97     {"role": "user", "content": f"Ответь на вопрос клиента. Не упоминай документ с информацией для \
#      98                                   ответа клиенту в ответе. Документ с информацией для ответа клиенту:\
#      99                                   {message_content}\n\nВопрос клиента: \n{query}"}
#     100 ]
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\langchain_community\vectorstores\faiss.py:548, in FAISS.similarity_search(self, query, k, filter, fetch_k, **kwargs)
#     528 def similarity_search(
#     529     self,
#     530     query: str,
#    (...)
#     534     **kwargs: Any,
#     535 ) -> List[Document]:
#     536     """Return docs most similar to query.
#     537
#     538     Args:
#    (...)
#     546         List of Documents most similar to the query.
#     547     """
# --> 548     docs_and_scores = self.similarity_search_with_score(
#     549         query, k, filter=filter, fetch_k=fetch_k, **kwargs
#     550     )
#     551     return [doc for doc, _ in docs_and_scores]
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\langchain_community\vectorstores\faiss.py:420, in FAISS.similarity_search_with_score(self, query, k, filter, fetch_k, **kwargs)
#     396 def similarity_search_with_score(
#     397     self,
#     398     query: str,
#    (...)
#     402     **kwargs: Any,
#     403 ) -> List[Tuple[Document, float]]:
#     404     """Return docs most similar to query.
#     405
#     406     Args:
#    (...)
#     418         L2 distance in float. Lower score represents more similarity.
#     419     """
# --> 420     embedding = self._embed_query(query)
#     421     docs = self.similarity_search_with_score_by_vector(
#     422         embedding,
#     423         k,
#    (...)
#     426         **kwargs,
#     427     )
#     428     return docs
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\langchain_community\vectorstores\faiss.py:155, in FAISS._embed_query(self, text)
#     153 def _embed_query(self, text: str) -> List[float]:
#     154     if isinstance(self.embedding_function, Embeddings):
# --> 155         return self.embedding_function.embed_query(text)
#     156     else:
#     157         return self.embedding_function(text)
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\langchain_openai\embeddings\base.py:509, in OpenAIEmbeddings.embed_query(self, text)
#     500 def embed_query(self, text: str) -> List[float]:
#     501     """Call out to OpenAI's embedding endpoint for embedding query text.
#     502
#     503     Args:
#    (...)
#     507         Embedding for the text.
#     508     """
# --> 509     return self.embed_documents([text])[0]
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\langchain_openai\embeddings\base.py:480, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     477 # NOTE: to keep things simple, we assume the list may contain texts longer
#     478 #       than the maximum context and use length-safe embedding function.
#     479 engine = cast(str, self.deployment)
# --> 480 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\langchain_openai\embeddings\base.py:290, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     288 else:
#     289     try:
# --> 290         encoding = tiktoken.encoding_for_model(model_name)
#     291     except KeyError:
#     292         encoding = tiktoken.get_encoding("cl100k_base")
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\tiktoken\model.py:101, in encoding_for_model(model_name)
#      96 def encoding_for_model(model_name: str) -> Encoding:
#      97     """Returns the encoding used by a model.
#      98
#      99     Raises a KeyError if the model name is not recognised.
#     100     """
# --> 101     return get_encoding(encoding_name_for_model(model_name))
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\tiktoken\registry.py:73, in get_encoding(encoding_name)
#      68     raise ValueError(
#      69         f"Unknown encoding {encoding_name}. Plugins found: {_available_plugin_modules()}"
#      70     )
#      72 constructor = ENCODING_CONSTRUCTORS[encoding_name]
# ---> 73 enc = Encoding(**constructor())
#      74 ENCODINGS[encoding_name] = enc
#      75 return enc
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\tiktoken_ext\openai_public.py:72, in cl100k_base()
#      71 def cl100k_base():
# ---> 72     mergeable_ranks = load_tiktoken_bpe(
#      73         "https://openaipublic.blob.core.windows.net/encodings/cl100k_base.tiktoken",
#      74         expected_hash="223921b76ee99bde995b7ff738513eef100fb51d18c93597a113bcffe865b2a7",
#      75     )
#      76     special_tokens = {
#      77         ENDOFTEXT: 100257,
#      78         FIM_PREFIX: 100258,
#    (...)
#      81         ENDOFPROMPT: 100276,
#      82     }
#      83     return {
#      84         "name": "cl100k_base",
#      85         "pat_str": r"""'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+""",
#      86         "mergeable_ranks": mergeable_ranks,
#      87         "special_tokens": special_tokens,
#      88     }
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\tiktoken\load.py:147, in load_tiktoken_bpe(tiktoken_bpe_file, expected_hash)
#     143 def load_tiktoken_bpe(
#     144     tiktoken_bpe_file: str, expected_hash: Optional[str] = None
#     145 ) -> dict[bytes, int]:
#     146     # NB: do not add caching to this function
# --> 147     contents = read_file_cached(tiktoken_bpe_file, expected_hash)
#     148     return {
#     149         base64.b64decode(token): int(rank)
#     150         for token, rank in (line.split() for line in contents.splitlines() if line)
#     151     }
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\tiktoken\load.py:64, in read_file_cached(blobpath, expected_hash)
#      61     except OSError:
#      62         pass
# ---> 64 contents = read_file(blobpath)
#      65 if expected_hash and not check_hash(contents, expected_hash):
#      66     raise ValueError(
#      67         f"Hash mismatch for data downloaded from {blobpath} (expected {expected_hash}). "
#      68         f"This may indicate a corrupted download. Please try again."
#      69     )
#
# File c:\Users\v.volkov\AppData\Local\miniconda3\envs\env3.9\lib\site-packages\tiktoken\load.py:25, in read_file(blobpath)
#      23         return f.read()
#      24 # avoiding blobfile for public files helps avoid auth issues, like MFA prompts
# ---> 25 resp = requests.get(blobpath)
#      26 resp.raise_for_status()
#      27 return resp.content
#
# File C:\Users\v.volkov\AppData\Roaming\Python\Python39\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File C:\Users\v.volkov\AppData\Roaming\Python\Python39\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File C:\Users\v.volkov\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File C:\Users\v.volkov\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File C:\Users\v.volkov\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='openaipublic.blob.core.windows.net', port=443): Max retries exceeded with url: /encodings/cl100k_base.tiktoken (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002762777B1C0>: Failed to resolve 'openaipublic.blob.core.windows.net' ([Errno 11001] getaddrinfo failed)"))

# %%
# запросы в fastapi_example
response = requests.get("http://127.0.0.1:5000/api/start")
print(response.text)

# %%
import requests

# использование кастомного chatgpt через кастомный api
payload = {"text":"На какой минимальный срок можно оформить КАСКО?"}
response = requests.post("http://127.0.0.1:5000/api/get_answer", json=payload)
print(response.text)
